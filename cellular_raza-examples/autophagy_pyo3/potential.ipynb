# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %% [markdown]
# ## Overall Shape

# %%
def lennard_jones(x, epsilon, sigma, bound, cutoff):
    s = 4*epsilon*((sigma/x)**12 - (sigma/x)**6)
    q = x<=cutoff
    return q * np.minimum(s, [bound])

def linear_jones(x, attracting, repelling, sigma, interaction_range, cutoff):
    return repelling*(x<=sigma) + np.abs()*(sigma<x)

sigma = 1.0
epsilon = 1.0
bound = 1.515
cutoff = 2.5

import scipy as sp
xdata = [0, sigma, 2*sigma, cutoff]
ydata = [bound, 0, -epsilon, 0]
fit_func = lambda x, a0, a2, a3, a4: a0 + a2*x**2 + a3*x**3 + a4*x**4
fit_params, _ = sp.optimize.curve_fit(fit_func, xdata, ydata)

fig, ax = plt.subplots()
x = np.linspace(0.001, 3.5*sigma, 200)
y1 = lennard_jones(x, epsilon, sigma, bound, cutoff)
y3 = linear_jones(x, epsilon, epsilon, sigma, bound, cutoff)
y2 = fit_func(x, *fit_params)

ax.plot(x, y1, label="Lennard-Jones")
ax.plot(x, y2, label="Fit")
ax.plot(x, y3, label="Linear Jones")

plt.show(fig)

# %% [markdown]
# ## Neighbors

# %%
def func(x):
    n = 2
    alpha = 1
    s = (x/alpha)**n/(1+(x/alpha)**n)
    return 0.5 + 0.5*s

x = np.linspace(0, 10)
y =  func(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show(fig)
